# %%
import pandas as pd
import glob
import math

# %%
SAMPLE = "./Commit_CSVs/Sample_Commits.csv"
PATH = './Commit_CSVs/[!Sample]*.csv'
PERCENTAGE = 0.01

# %% [markdown]
# Read all files from Commit_CSVs folder and create a dataframe

# %%
df = pd.concat(map(pd.read_csv, glob.glob(PATH)))

# %% [markdown]
# Takes a sample of all commits. Size is dependet on the indicated percentage. If there is already an existing Sample_Commits.csv file it gets replaced.

# %%
number_of_commits = df.shape[0]
sample_size = math.ceil(number_of_commits * PERCENTAGE)
sample = df.sample(sample_size)
sample.to_csv(SAMPLE)
sample
# Out:
#                                      Commit_ID      Contributor        Date  \
# 1759  62b86332a145588f1da3228446b832389b610495     Rick Waldron  2015-09-23
# 970   013dc86449a2916204cf6eb016768706f98834e1      deadprogram  2015-09-08
# 697   a735a62b05b1f93e54fec620ec3936e0425d9082   Alexander Grau  2015-05-19
# 320   8e01fed143c6fbd5239a93bedcdb64f2eb245102    Bertus Kruger  2013-03-13
# 2122  096e470e0b5ff43bc5eae8c1ca2e5dc144c8655c     Rick Waldron  2016-03-10
# ...                                        ...              ...         ...
# 278   ea4c339da633e26408c95bda34eda2977ab78897           Hypfer  2020-02-17
# 413   cd1a016b2bc05788ed9860eec1e1fe4040734e37   Adrian Zankich  2014-11-19
# 961   442397bf460f1c5dead2594375e5a98ceff9f0bc  Sean D'Epagnier  2018-07-26
# 139   5319cfc092e00b547d676f8612a86b16e013eda3      John Schulz  2012-11-19
# 154   c3a0a8d441f2e69a655beaffe278f49972b84b5f  Sean D'Epagnier  1999-09-01
#
#                                                 Message  \
# 1759                                            v0.8.92
# 970                                     Update RELEASES
# 697                                          csv output
# 320     Update gcode.cRemoved the home_select variable.
# 2122                      Expander: add missing example
# ...                                                 ...
# 278            Properly handle cloud keep-alive packets
# 413        Update edison package for new gpio interface
# 961   fix typo on serialprobe detection (affects ope...
# 139   Use new structure for `demo` & `rawMeasures` i...
# 154                                 improve log message
#
#                                                   Files      Branch  \
# 1759                                   ['package.json']  {'master'}
# 970                                     ['RELEASES.md']  {'master'}
# 697   ['drivecontrol.ino,motorcontrol.cpp,motorcontr...  {'master'}
# 320                                         ['gcode.c']  {'master'}
# 2122  ['keypad-MPR121.md,expander-CD74HC4067_NANO_BA...  {'master'}
# ...                                                 ...         ...
# 278                                   ['MiioSocket.js']  {'master'}
# 413   ['edison_adaptor.go,edison_adaptor_test.go,pwm...  {'master'}
# 961                                  ['serialprobe.py']  {'master'}
# 139                                 ['parseNavdata.js']  {'master'}
# 154                                      ['sensors.py']  {'master'}
#
#          Repository
# 1759    johnny-five
# 970           cylon
# 697       ardumower
# 320            grbl
# 2122    johnny-five
# ...             ...
# 278        Valetudo
# 413           gobot
# 961         pypilot
# 139   node-ar-drone
# 154         pypilot
#
# [111 rows x 7 columns]
